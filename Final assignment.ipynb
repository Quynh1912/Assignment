# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# __Le Thi Nhu Quynh__
# Wholesale Banking Specialist

# %% [markdown]
# _I am interested ub data science because it serves my work: solving Bank's problems (e.g. risk management, business...) based on data_

# %% [markdown]
# ### Calculation

# %%
1+1
# Out:
# 2

# %% [markdown]
# |No.|Name|Date of birth|
# |--|--|--|
# |1|Quynh|19121990|
# |2|Ninh|30042000|
#
# 1. How many columns are there?
# 2. How many rows are there?
#
# --------------------------
